# %% [markdown]
# Project 5: Human Development index
# Name: Tenzin Uden
# Sources: https://ourworldindata.org/human-development-index

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_HDI= pd.read_csv('human-development-index.csv')
df_HDI
# Out:
#            Entity Code  Year  Human Development Index
# 0     Afghanistan  AFG  1990                    0.273
# 1     Afghanistan  AFG  1991                    0.279
# 2     Afghanistan  AFG  1992                    0.287
# 3     Afghanistan  AFG  1993                    0.297
# 4     Afghanistan  AFG  1994                    0.292
# ...           ...  ...   ...                      ...
# 5918     Zimbabwe  ZWE  2017                    0.594
# 5919     Zimbabwe  ZWE  2018                    0.602
# 5920     Zimbabwe  ZWE  2019                    0.601
# 5921     Zimbabwe  ZWE  2020                    0.600
# 5922     Zimbabwe  ZWE  2021                    0.593
#
# [5923 rows x 4 columns]

# %%
#checking on whihc year needed the most UN peacekeeping troups
df_HDI.min()
# Out:
# /var/folders/9s/_42jg5ds12l364yqldkmcvvw0000gn/T/ipykernel_44619/3496261803.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_HDI.min()
# Entity                     Afghanistan
# Year                              1990
# Human Development Index          0.216
# dtype: object

# %%
df_HDI.max()
# Out:
# /var/folders/9s/_42jg5ds12l364yqldkmcvvw0000gn/T/ipykernel_44619/3868028447.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_HDI.max()
# Entity                     Zimbabwe
# Year                           2021
# Human Development Index       0.962
# dtype: object

# %%
df_HDI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5923 entries, 0 to 5922
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Entity                   5923 non-null   object
#  1   Code                     5603 non-null   object
#  2   Year                     5923 non-null   int64
#  3   Human Development Index  5923 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 185.2+ KB

# %%
#Japan being considered as one of the healthiest country I wanted to check out Japan's HDI over the years.
df_HDI_Japan= df_HDI[df_HDI["Entity"]=='Japan']
df_HDI_Japan
# Out:
#      Entity Code  Year  Human Development Index
# 2639  Japan  JPN  1990                    0.845
# 2640  Japan  JPN  1991                    0.849
# 2641  Japan  JPN  1992                    0.850
# 2642  Japan  JPN  1993                    0.855
# 2643  Japan  JPN  1994                    0.861
# 2644  Japan  JPN  1995                    0.863
# 2645  Japan  JPN  1996                    0.868
# 2646  Japan  JPN  1997                    0.871
# 2647  Japan  JPN  1998                    0.871
# 2648  Japan  JPN  1999                    0.872
# 2649  Japan  JPN  2000                    0.877
# 2650  Japan  JPN  2001                    0.880
# 2651  Japan  JPN  2002                    0.882
# 2652  Japan  JPN  2003                    0.884
# 2653  Japan  JPN  2004                    0.888
# 2654  Japan  JPN  2005                    0.889
# 2655  Japan  JPN  2006                    0.892
# 2656  Japan  JPN  2007                    0.895
# 2657  Japan  JPN  2008                    0.895
# ...

# %%
fig, axs = plt.subplots(figsize=(10, 8))

df_HDI_Japan['Human Development Index'].plot(kind='line', rot=60, ax=axs)


plt.xlabel("Year")  # custom x label using Matplotlib

plt.ylabel("HDI")
plt.title('Japan')

plt.show()

# %%
sns.catplot(data=df_HD1I, x="Year", y="Human Development Index")

# %%
sns.displot(df_HDI,x='Human Development Index',hue='Year')

# %%
sns.displot(df_HDI,x='Human Development Index',hue='Entity')
